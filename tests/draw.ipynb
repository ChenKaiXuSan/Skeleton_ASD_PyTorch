# %%
from torchmetrics.classification import MulticlassConfusionMatrix

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# 设置字体和标题样式
plt.rcParams.update({'font.size': 30, 'font.family': 'sans-serif'})

# 假设的混淆矩阵数据
confusion_matrix_data = np.array([[0.4074, 0.5926], [0.3704, 0.6296]])

axis_labels = ['ASD', 'non_ASD']

# 使用matplotlib和seaborn绘制混淆矩阵
plt.figure(figsize=(8, 6))
sns.heatmap(confusion_matrix_data, annot=True, fmt='.4f', cmap='Reds', xticklabels=axis_labels, yticklabels=axis_labels, vmin=0, vmax=1, annot_kws={'color': 'black'})
plt.title('Doctor 1 result', fontsize=20)
plt.ylabel('Actual Label', fontsize=20)
plt.xlabel('Predicted Label', fontsize=20)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# 设置字体和标题样式
plt.rcParams.update({'font.size': 30, 'font.family': 'sans-serif'})

# 假设的混淆矩阵数据
confusion_matrix_data = np.array([[0.4815, 0.5185], [0.3889, 0.6111]])

axis_labels = ['ASD', 'non_ASD']

# 使用matplotlib和seaborn绘制混淆矩阵
plt.figure(figsize=(8, 6))
sns.heatmap(confusion_matrix_data, annot=True, fmt='.4f', cmap='Reds', xticklabels=axis_labels, yticklabels=axis_labels, vmin=0, vmax=1, annot_kws={'color': 'black'})
plt.title('Doctor 2 result', fontsize=20)
plt.ylabel('Actual Label', fontsize=20)
plt.xlabel('Predicted Label', fontsize=20)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# 设置字体和标题样式
plt.rcParams.update({'font.size': 30, 'font.family': 'sans-serif'})

# 假设的混淆矩阵数据
confusion_matrix_data = np.array([[0.8860, 0.1140], [0.5000, 0.5000]])

axis_labels = ['ASD', 'non_ASD']

# 使用matplotlib和seaborn绘制混淆矩阵
plt.figure(figsize=(8, 6))
sns.heatmap(confusion_matrix_data, annot=True, fmt='.4f', cmap='Reds', xticklabels=axis_labels, yticklabels=axis_labels, vmin=0, vmax=1, annot_kws={'color': 'black'})
plt.title('Existing method', fontsize=20)
plt.ylabel('Actual Label', fontsize=20)
plt.xlabel('Predicted Label', fontsize=20)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# 设置字体和标题样式
plt.rcParams.update({'font.size': 30, 'font.family': 'sans-serif'})

# 假设的混淆矩阵数据
confusion_matrix_data = np.array([[0.8512, 0.1488], [0.3580, 0.6420]])

axis_labels = ['ASD', 'non_ASD']

# 使用matplotlib和seaborn绘制混淆矩阵
plt.figure(figsize=(8, 6))
sns.heatmap(confusion_matrix_data, annot=True, fmt='.4f', cmap='Reds', xticklabels=axis_labels, yticklabels=axis_labels, vmin=0, vmax=1, annot_kws={'color': 'black'})
plt.title('Proposed method', fontsize=20)
plt.ylabel('Actual Label', fontsize=20)
plt.xlabel('Predicted Label', fontsize=20)
plt.show()
